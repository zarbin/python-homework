# %%
# -*- coding: UTF-8 -*-

#Import libraries
import csv
from pathlib import Path

#Set file paths for menu_data.csv and sales_data.csv
menu_filepath = Path('menu_data.csv')
sales_filepath = Path('sales_data.csv')

#Initialize list objects to hold our menu and sales data
menu = []
sales = []

#Read in the menu data into the menu list
#Open the csv file as an object
with open(menu_filepath, newline='') as csvfile:

    # Pass in the csv file to the csv.reader() function
    csvreader = csv.reader(csvfile, delimiter=',')

    #Read the header row.  next reads the first line and then bypasses it.. 
    header = next(csvreader)

    #Read each row of data after the header
    menu = list(csvreader)
    #print(menu)


#Read in the sales data into the sales list
with open(sales_filepath, newline='') as csvfile:

    # Pass in the csv file to the csv.reader() function
    csvreader = csv.reader(csvfile, delimiter=',')

    #Read the header row.  next reads the first line and then bypasses it.. 
    header = next(csvreader)

    #Read each row of data after the header
    sales = list(csvreader)
    #print(sales)



#Initialize dict object to hold our key-value pairs of items and metrics
report = {}

# Initialize a row counter variable
row_count = 0

# @TODO: Loop over every row in the sales list object
for row in sales:

    # Line_Item_ID,Date,Credit_Card_Number,Quantity,Menu_Item
    #Initialize sales data variables
    Line_Item_ID = sales[0]
    Date = sales[1]
    Credit_Card_Number = sales[2]
    Quantity = sales[3]
    Menu_Item = sales[4]

    print(sales)

    # @TODO:
    # If the item value not in the report, add it as a new entry with initialized metrics
    # Naming convention allows the keys to be ordered in logical fashion, count, revenue, cost, profit








    # @TODO: For every row in our sales data, loop over the menu records to determine a match


        # Item,Category,Description,Price,Cost
        # @TODO: Initialize menu data variables




        # @TODO: Calculate profit of each item in the menu data


        # @TODO: If the item value in our sales data is equal to the any of the items in the menu, then begin tracking metrics for that item


            # @TODO: Print out matching menu data






            # @TODO: Cumulatively add up the metrics for each item key





        # @TODO: Else, the sales item does not equal any fo the item in the menu data, therefore no match



    # @TODO: Increment the row counter by 1
    #row_count += 1


# @TODO: Print total number of records in sales data
# do i need a counter for this?  Use row_counter above




# @TODO: Write out report to a text file (won't appear on the command line output)
#output report to text file
# Set the output file path
#output_path = Path("Financial_Analysis.txt")

# Open a file given the output path and print results
#with open(output_path, 'w') as file:
#    file.write("Financial Analysis\n")
# Out:
# ]
# ['73852', '12-30-2018', '1611012023385007', '1', 'tori paitan ramen']
# ['73853', '12-30-2018', '4013815260113196', '2', 'shio ramen']
# ['73854', '12-30-2018', '4013815260113196', '2', 'shio ramen']
# ['73855', '12-30-2018', '6288752350766002', '1', 'shio ramen']
# ['73856', '12-30-2018', '6288752350766002', '1', 'shio ramen']
# ['73857', '12-30-2018', '3770036311184597', '4', 'spicy miso ramen']
# ['73858', '12-30-2018', '3770036311184597', '4', 'spicy miso ramen']
# ['73859', '12-30-2018', '8865807323169210', '1', 'tori paitan ramen']
# ['73860', '12-30-2018', '8865807323169210', '1', 'tori paitan ramen']
# ['73861', '12-30-2018', '8652377986898589', '1', 'truffle butter ramen']
# ['73862', '12-30-2018', '8652377986898589', '1', 'truffle butter ramen']
# ['73863', '12-30-2018', '2924604449172499', '1', 'miso crab ramen']
# ['73864', '12-30-2018', '2924604449172499', '1', 'miso crab ramen']
# ['73865', '12-30-2018', '2479795673224135', '4', 'nagomi shoyu']
# ['73866', '12-30-2018', '2479795673224135', '4', 'nagomi shoyu']
# ['73867', '12-30-2018', '7187342431192237', '1', 'truffle butter ramen']
# ['73868', '12-30-2018', '7187342431192237', '1', 'truffle butter ramen']
# ['73869', '12-30-2018', '4627206665884368', '2', 'truffle butter ramen']
# ['73870', '12-30-2018', '4627206665884368', '2', 'truffle butter ramen']
# ['73871', '12-30-2018', '7913476371126522', '1', 'vegetarian curry + king trumpet mushroom ramen']
# ['73872', '12-30-2018', '7913476371126522', '1', 'vegetarian curry + king trumpet mushroom ramen']
# ['73873', '12-30-2018', '5441728824147974', '1', 'miso crab ramen']
# ['73874', '12-30-2018', '5441728824147974', '1', 'miso crab ramen']
# ['73875', '12-30-2018', '9416345701720973', '1', 'nagomi shoyu']
# ['73876', '12-30-2018', '9416345701720973', '1', 'nagomi shoyu']
# ['73877', '12-30-2018', '8870147602474129', '1', 'vegetarian spicy miso']
# ['73878', '12-30-2018', '8870147602474129', '1', 'vegetarian spicy miso']
# ['73879', '12-30-2018', '1729711219897576', '1', 'vegetarian curry + king trumpet mushroom ramen']
# ['73880', '12-30-2018', '1729711219897576', '1', 'vegetarian curry + king trumpet mushroom ramen']
# ['73881', '12-30-2018', '7621179723726074', '1', 'tori paitan ramen']
# ['73882', '12-30-2018', '7621179723726074', '1', 'tori paitan ramen']
# ['73883', '12-30-2018', '2241025691021837', '1', 'tonkotsu ramen']
# ['73884', '12-30-2018', '2241025691021837', '1', 'tonkotsu ramen']
# ['73885', '12-30-2018', '3403276542971431', '1', 'nagomi shoyu']
# ['73886', '12-30-2018', '3403276542971431', '1', 'nagomi shoyu']
# ['73887', '12-30-2018', '8096698515647224', '1', 'soft-shell miso crab ramen']
# ['73888', '12-30-2018', '8096698515647224', '1', 'soft-shell miso crab ramen']
# ['73889', '12-30-2018', '9896073389710967', '1', 'truffle butter ramen']
# ['73890', '12-30-2018', '9896073389710967', '1', 'truffle butter ramen']
# ['73891', '12-30-2018', '5955302238459753', '1', 'miso crab ramen']
# ['73892', '12-30-2018', '5955302238459753', '1', 'miso crab ramen']
# ['73893', '12-30-2018', '7314077148821758', '3', 'spicy miso ramen']
# ['73894', '12-30-2018', '7314077148821758', '3', 'spicy miso ramen']
# ['73895', '12-30-2018', '9785078736740353', '3', 'vegetarian curry + king trumpet mushroom ramen']
# ['73896', '12-30-2018', '9785078736740353', '3', 'vegetarian curry + king trumpet mushroom ramen']
# ['73897', '12-30-2018', '8810542153931476', '1', 'spicy miso ramen']
# ['73898', '12-30-2018', '8810542153931476', '1', 'spicy miso ramen']
# ['73899', '12-30-2018', '5782369038056670', '1', 'spicy miso ramen']
# ['73900', '12-30-2018', '5782369038056670', '1', 'spicy miso ramen']
# ['73901', '12-30-2018', '8322313558517801', '1', 'truffle butter ramen']
# ['73902', '12-30-2018', '8322313558517801', '1', 'truffle butter ramen']
# ['73903', '12-30-2018', '9489269307972066', '1', 'burnt garlic tonkotsu ramen']
# ['73904', '12-30-2018', '9489269307972066', '1', 'burnt garlic tonkotsu ramen']
# ['73905', '12-30-2018', '5482452083924158', '1', 'truffle butter ramen']
# ['73906', '12-30-2018', '5482452083924158', '1', 'truffle butter ramen']
# ['73907', '12-30-2018', '5350457032515731', '1', 'truffle butter ramen']
# ['73908', '12-30-2018', '5350457032515731', '1', 'truffle butter ramen']
# ['73909', '12-30-2018', '8925144323653359', '1', 'tori paitan ramen']
# ['73910', '12-30-2018', '8925144323653359', '1', 'tori paitan ramen']
# ['73911', '12-30-2018', '5879466117538783', '3', 'tonkotsu ramen']
# ['73912', '12-30-2018', '5879466117538783', '3', 'tonkotsu ramen']
# ['73913', '12-30-2018', '4593816312267712', '2', 'vegetarian spicy miso']
# ['73914', '12-30-2018', '4593816312267712', '2', 'vegetarian spicy miso']
# ['73915', '12-30-2018', '2471751884699481', '1', 'soft-shell miso crab ramen']
# ['73916', '12-30-2018', '2471751884699481', '1', 'soft-shell miso crab ramen']
# ['73917', '12-30-2018', '4999858198423021', '1', 'truffle butter ramen']
# ['73918', '12-30-2018', '4999858198423021', '1', 'truffle butter ramen']
# ['73919', '12-30-2018', '1390949598830836', '1', 'truffle butter ramen']
# ['73920', '12-30-2018', '1390949598830836', '1', 'truffle butter ramen']
# ['73921', '12-30-2018', '829109887058308', '1', 'vegetarian spicy miso']
# ['73922', '12-30-2018', '829109887058308', '1', 'vegetarian spicy miso']
# ['73923', '12-30-2018', '1693981427721338', '1', 'burnt garlic tonkotsu ramen']
# ['73924', '12-30-2018', '1693981427721338', '1', 'burnt garlic tonkotsu ramen']
# ['73925', '12-30-2018', '3446762393841714', '1', 'tori paitan ramen']
# ['73926', '12-30-2018', '3446762393841714', '1', 'tori paitan ramen']
# ['73927', '12-30-2018', '8179817611350385', '1', 'truffle butter ramen']
# ['73928', '12-30-2018', '8179817611350385', '1', 'truffle butter ramen']
# ['73929', '12-30-2018', '2836805140860971', '1', 'miso crab ramen']
# ['73930', '12-30-2018', '2836805140860971', '1', 'miso crab ramen']
# ['73931', '12-30-2018', '4000885857585393', '1', 'soft-shell miso crab ramen']
# ['73932', '12-30-2018', '4000885857585393', '1', 'soft-shell miso crab ramen']
# ['73933', '12-30-2018', '9312695325065236', '3', 'truffle butter ramen']
# ['73934', '12-30-2018', '9312695325065236', '3', 'truffle butter ramen']
# ['73935', '12-30-2018', '3038432580898346', '1', 'shio ramen']
# ['73936', '12-30-2018', '3038432580898346', '1', 'shio ramen']
# ['73937', '12-30-2018', '7747402939115611', '1', 'burnt garlic tonkotsu ramen']
# ['73938', '12-30-2018', '7747402939115611', '1', 'burnt garlic tonkotsu ramen']
# ['73939', '12-30-2018', '9583790928472629', '1', 'vegetarian curry + king trumpet mushroom ramen']
# ['73940', '12-30-2018', '9583790928472629', '1', 'vegetarian curry + king trumpet mushroom ramen']
# ['73941', '12-30-2018', '2867231266133423', '1', 'truffle butter ramen']
# ['73942', '12-30-2018', '2867231266133423', '1', 'truffle butter ramen']
# ['73943', '12-30-2018', '9308866623202183', '1', 'shio ramen']
# ['73944', '12-30-2018', '9308866623202183', '1', 'shio ramen']
# ['73945', '12-31-2018', '3118706849259484', '1', 'burnt garlic tonkotsu ramen']
# ['73946', '12-31-2018', '3118706849259484', '1', 'burnt garlic tonkotsu ramen']
# ['73947', '12-31-2018', '4265093603543188', '2', 'vegetarian spicy miso']
# ['73948', '12-31-2018', '4265093603543188', '2', 'vegetarian spicy miso']
# ['73949', '12-31-2018', '7299965695706581', '1', 'vegetarian curry + king trumpet mushroom ramen']
# ['73950', '12-31-2018', '7299965695706581', '1', 'vegetarian curry + king trumpet mushroom ramen']
# ['73951', '12-31-2018', '8012031895170505', '3', 'miso crab ramen']
# ['73952', '12-31-2018', '8012031895170505', '3', 'miso crab ramen']
# ['73953', '12-31-2018', '7106762757245227', '2', 'vegetarian spicy miso']
# ['73954', '12-31-2018', '7106762757245227', '2', 'vegetarian spicy miso']
# ['73955', '12-31-2018', '5677378850619508', '1', 'tori paitan ramen']
# ['73956', '12-31-2018', '5677378850619508', '1', 'tori paitan ramen']
# ['73957', '12-31-2018', '6748431381197071', '1', 'miso crab ramen']
# ['73958', '12-31-2018', '6748431381197071', '1', 'miso crab ramen']
# ['73959', '12-31-2018', '9026896555998863', '1', 'spicy miso ramen']
# ['73960', '12-31-2018', '9026896555998863', '1', 'spicy miso ramen']
# ['73961', '12-31-2018', '170353525361697', '1', 'vegetarian spicy miso']
# ['73962', '12-31-2018', '170353525361697', '1', 'vegetarian spicy miso']
# ['73963', '12-31-2018', '2666054242950936', '1', 'tori paitan ramen']
# ['73964', '12-31-2018', '2666054242950936', '1', 'tori paitan ramen']
# ['73965', '12-31-2018', '1259642520071684', '1', 'vegetarian curry + king trumpet mushroom ramen']
# ['73966', '12-31-2018', '1259642520071684', '1', 'vegetarian curry + king trumpet mushroom ramen']
# ['73967', '12-31-2018', '2717976417051629', '1', 'burnt garlic tonkotsu ramen']
# ['73968', '12-31-2018', '2717976417051629', '1', 'burnt garlic tonkotsu ramen']
# ['73969', '12-31-2018', '7723449125453287', '1', 'tori paitan ramen']
# ['73970', '12-31-2018', '7723449125453287', '1', 'tori paitan ramen']
# ['73971', '12-31-2018', '3125458480099328', '1', 'tonkotsu ramen']
# ['73972', '12-31-2018', '3125458480099328', '1', 'tonkotsu ramen']
# ['73973', '12-31-2018', '1711785263136921', '1', 'miso crab ramen']
# ['73974', '12-31-2018', '1711785263136921', '1', 'miso crab ramen']
# ['73975', '12-31-2018', '265827176843534', '2', 'vegetarian curry + king trumpet mushroom ramen']
# ['73976', '12-31-2018', '265827176843534', '2', 'vegetarian curry + king trumpet mushroom ramen']
# ['73977', '12-31-2018', '8872272369902134', '1', 'burnt garlic tonkotsu ramen']
# ['73978', '12-31-2018', '8872272369902134', '1', 'burnt garlic tonkotsu ramen']
# ['73979', '12-31-2018', '899335907865201', '1', 'vegetarian spicy miso']
# ['73980', '12-31-2018', '899335907865201', '1', 'vegetarian spicy miso']
# ['73981', '12-31-2018', '291198679010682', '1', 'truffle butter ramen']
# ['73982', '12-31-2018', '291198679010682', '1', 'truffle butter ramen']
# ['73983', '12-31-2018', '8856608136652545', '1', 'nagomi shoyu']
# ['73984', '12-31-2018', '8856608136652545', '1', 'nagomi shoyu']
# ['73985', '12-31-2018', '3150340589197932', '1', 'nagomi shoyu']
# ['73986', '12-31-2018', '3150340589197932', '1', 'nagomi shoyu']
# ['73987', '12-31-2018', '5775687460151781', '1', 'miso crab ramen']
# ['73988', '12-31-2018', '5775687460151781', '1', 'miso crab ramen']
# ['73989', '12-31-2018', '9370771523174605', '1', 'spicy miso ramen']
# ['73990', '12-31-2018', '9370771523174605', '1', 'spicy miso ramen']
# ['73991', '12-31-2018', '3638148551268225', '1', 'vegetarian spicy miso']
# ['73992', '12-31-2018', '3638148551268225', '1', 'vegetarian spicy miso']
# ['73993', '12-31-2018', '6985079197638963', '1', 'miso crab ramen']
# ['73994', '12-31-2018', '6985079197638963', '1', 'miso crab ramen']
# ['73995', '12-31-2018', '8667107494331585', '1', 'spicy miso ramen']
# ['73996', '12-31-2018', '8667107494331585', '1', 'spicy miso ramen']
# ['73997', '12-31-2018', '4773976952083319', '3', 'vegetarian spicy miso']
# ['73998', '12-31-2018', '4773976952083319', '3', 'vegetarian spicy miso']
# ['73999', '12-31-2018', '7149009297454140', '4', 'truffle butter ramen']
# ['74000', '12-31-2018', '7149009297454140', '4', 'truffle butter ramen']
# ['74001', '12-31-2018', '9919788788224883', '1', 'spicy miso ramen']
# ['74002', '12-31-2018', '9919788788224883', '1', 'spicy miso ramen']
# ['74003', '12-31-2018', '3984840691852411', '1', 'vegetarian curry + king trumpet mushroom ramen']
# ['74004', '12-31-2018', '3984840691852411', '1', 'vegetarian curry + king trumpet mushroom ramen']
# ['74005', '12-31-2018', '7349133459084047', '1', 'spicy miso ramen']
# ['74006', '12-31-2018', '7349133459084047', '1', 'spicy miso ramen']
# ['74007', '12-31-2018', '4286868988719826', '2', 'vegetarian curry + king trumpet mushroom ramen']
# ['74008', '12-31-2018', '4286868988719826', '2', 'vegetarian curry + king trumpet mushroom ramen']
# ['74009', '12-31-2018', '3254873492314332', '1', 'miso crab ramen']
# ['74010', '12-31-2018', '3254873492314332', '1', 'miso crab ramen']
# ['74011', '12-31-2018', '1973920297171442', '2', 'tori paitan ramen']
# ['74012', '12-31-2018', '1973920297171442', '2', 'tori paitan ramen']
# ['74013', '12-31-2018', '8010983107118588', '1', 'spicy miso ramen']
# ['74014', '12-31-2018', '8010983107118588', '1', 'spicy miso ramen']
# ['74015', '12-31-2018', '5974504126807006', '1', 'vegetarian spicy miso']
# ['74016', '12-31-2018', '5974504126807006', '1', 'vegetarian spicy miso']
# ['74017', '12-31-2018', '1300639714141442', '2', 'vegetarian spicy miso']
# ['74018', '12-31-2018', '1300639714141442', '2', 'vegetarian spicy miso']
# ['74019', '12-31-2018', '4802468108571730', '1', 'soft-shell miso crab ramen']
# ['74020', '12-31-2018', '4802468108571730', '1', 'soft-shell miso crab ramen']
# ['74021', '12-31-2018', '3340027141744962', '2', 'burnt garlic tonkotsu ramen']
# ['74022', '12-31-2018', '3340027141744962', '2', 'burnt garlic tonkotsu ramen']
# ['74023', '12-31-2018', '8028924930690130', '1', 'miso crab ramen']
# ['74024', '12-31-2018', '8028924930690130', '1', 'miso crab ramen']
# ['74025', '12-31-2018', '4404274864240810', '1', 'tori paitan ramen']
# ['74026', '12-31-2018', '4404274864240810', '1', 'tori paitan ramen']
# ['74027', '12-31-2018', '6228520607204869', '1', 'nagomi shoyu']
# ['74028', '12-31-2018', '6228520607204869', '1', 'nagomi shoyu']
# ['74029', '12-31-2018', '5611642202593518', '1', 'tonkotsu ramen']
# ['74030', '12-31-2018', '5611642202593518', '1', 'tonkotsu ramen']
# ['74031', '12-31-2018', '2297464398641424', '1', 'tonkotsu ramen']
# ['74032', '12-31-2018', '2297464398641424', '1', 'tonkotsu ramen']
# ['74033', '12-31-2018', '9750957466915125', '1', 'soft-shell miso crab ramen']
# ['74034', '12-31-2018', '9750957466915125', '1', 'soft-shell miso crab ramen']
# ['74035', '12-31-2018', '8180187169868389', '1', 'tori paitan ramen']
# ['74036', '12-31-2018', '8180187169868389', '1', 'tori paitan ramen']
# ['74037', '12-31-2018', '7362804082005607', '2', 'burnt garlic tonkotsu ramen']
# ['74038', '12-31-2018', '7362804082005607', '2', 'burnt garlic tonkotsu ramen']
# ['74039', '12-31-2018', '4469105551669677', '3', 'nagomi shoyu']
# ['74040', '12-31-2018', '4469105551669677', '3', 'nagomi shoyu']
# ['74041', '12-31-2018', '6579405517198096', '1', 'tori paitan ramen']
# ['74042', '12-31-2018', '6579405517198096', '1', 'tori paitan ramen']
# ['74043', '12-31-2018', '2104551880811024', '4', 'spicy miso ramen']
# ['74044', '12-31-2018', '2104551880811024', '4', 'spicy miso ramen']
# ['74045', '12-31-2018', '4150598284813409', '1', 'vegetarian curry + king trumpet mushroom ramen']
# ['74046', '12-31-2018', '4150598284813409', '1', 'vegetarian curry + king trumpet mushroom ramen']
# ['74047', '12-31-2018', '2562424383466255', '1', 'nagomi shoyu']
# ['74048', '12-31-2018', '2562424383466255', '1', 'nagomi shoyu']
# ['74049', '12-31-2018', '7271712079983674', '1', 'tori paitan ramen']
# ['74050', '12-31-2018', '7271712079983674', '1', 'tori paitan ramen']
# ['74051', '12-31-2018', '9253113418778025', '1', 'burnt garlic tonkotsu ramen']
# ['74052', '12-31-2018', '9253113418778025', '1', 'burnt garlic tonkotsu ramen']
# ['74053', '12-31-2018', '1660710537850732', '1', 'miso crab ramen']
# ['74054', '12-31-2018', '1660710537850732', '1', 'miso crab ramen']
# ['74055', '12-31-2018', '7656540884800478', '2', 'truffle butter ramen']
# ['74056', '12-31-2018', '7656540884800478', '2', 'truffle butter ramen']
# ['74057', '12-31-2018', '4071878107358617', '3', 'soft-shell miso crab ramen']
# ['74058', '12-31-2018', '4071878107358617', '3', 'soft-shell miso crab ramen']
# ['74059', '12-31-2018', '3199373106777395', '2', 'burnt garlic tonkotsu ramen']
# ['74060', '12-31-2018', '3199373106777395', '2', 'burnt garlic tonkotsu ramen']
# ['74061', '12-31-2018', '2447882037183862', '1', 'nagomi shoyu']
# ['74062', '12-31-2018', '2447882037183862', '1', 'nagomi shoyu']
# ['74063', '12-31-2018', '4396016557422914', '1', 'shio ramen']
# ['74064', '12-31-2018', '4396016557422914', '1', 'shio ramen']
# ['74065', '12-31-2018', '344806023086415', '1', 'nagomi shoyu']
# ['74066', '12-31-2018', '344806023086415', '1', 'nagomi shoyu']
# ['74067', '12-31-2018', '1430752416248108', '1', 'burnt garlic tonkotsu ramen']
# ['74068', '12-31-2018', '1430752416248108', '1', 'burnt garlic tonkotsu ramen']
# ['74069', '12-31-2018', '9641894213232480', '1', 'miso crab ramen']
# ['74070', '12-31-2018', '9641894213232480', '1', 'miso crab ramen']
# ['74071', '12-31-2018', '4549170897530748', '4', 'burnt garlic tonkotsu ramen']
# ['74072', '12-31-2018', '4549170897530748', '4', 'burnt garlic tonkotsu ramen']
# ['74073', '12-31-2018', '2671445923448828', '4', 'miso crab ramen']
# ['74074', '12-31-2018', '2671445923448828', '4', 'miso crab ramen']
# ['74075', '12-31-2018', '6114674334051074', '1', 'miso crab ramen']
# ['74076', '12-31-2018', '6114674334051074', '1', 'miso crab ramen']
# ['74077', '12-31-2018', '2614269119368992', '1', 'burnt garlic tonkotsu ramen']
# ['74078', '12-31-2018', '2614269119368992', '1', 'burnt garlic tonkotsu ramen']
# ['74079', '12-31-2018', '2606053549476760', '1', 'tori paitan ramen']
# ['74080', '12-31-2018', '2606053549476760', '1', 'tori paitan ramen']
# ['74081', '12-31-2018', '1743945407975502', '1', 'spicy miso ramen']
# ['74082', '12-31-2018', '1743945407975502', '1', 'spicy miso ramen']
# ['74083', '12-31-2018', '9112067238589258', '1', 'truffle butter ramen']
# ['74084', '12-31-2018', '9112067238589258', '1', 'truffle butter ramen']
# ['74085', '12-31-2018', '9803783656690951', '1', 'vegetarian curry + king trumpet mushroom ramen']
# ['74086', '12-31-2018', '9803783656690951', '1', 'vegetarian curry + king trumpet mushroom ramen']
# ['74087', '12-31-2018', '3982461499707633', '1', 'tori paitan ramen']
# ['74088', '12-31-2018', '3982461499707633', '1', 'tori paitan ramen']
# ['74089', '12-31-2018', '4475582533506498', '1', 'vegetarian spicy miso']
# ['74090', '12-31-2018', '4475582533506498', '1', 'vegetarian spicy miso']
# ['74091', '12-31-2018', '5548757629530940', '1', 'shio ramen']
# ['74092', '12-31-2018', '5548757629530940', '1', 'shio ramen']
# ['74093', '12-31-2018', '7764278947998083', '1', 'miso crab ramen']
# ['74094', '12-31-2018', '7764278947998083', '1', 'miso crab ramen']
# ['74095', '12-31-2018', '4071127199442847', '1', 'vegetarian spicy miso']
# ['74096', '12-31-2018', '4071127199442847', '1', 'vegetarian spicy miso']
# ['74097', '12-31-2018', '1412285699513073', '2', 'nagomi shoyu']
# ['74098', '12-31-2018', '1412285699513073', '2', 'nagomi shoyu']
# ['74099', '12-31-2018', '3274643652273312', '1', 'tonkotsu ramen']
# ['74100', '12-31-2018', '3274643652273312', '1', 'tonkotsu ramen']
# ['74101', '12-31-2018', '5443168464731638', '1', 'truffle butter ramen']
# ['74102', '12-31-2018', '5443168464731638', '1', 'truffle butter ramen']
# ['74103', '12-31-2018', '8614644370397100', '1', 'tonkotsu ramen']
# ['74104', '12-31-2018', '8614644370397100', '1', 'tonkotsu ramen']
# ['74105', '12-31-2018', '9794251638634207', '1', 'shio ramen']
# ['74106', '12-31-2018', '9794251638634207', '1', 'shio ramen']
# ['74107', '12-31-2018', '3906983012249654', '1', 'soft-shell miso crab ramen']
# ['74108', '12-31-2018', '3906983012249654', '1', 'soft-shell miso crab ramen']
# ['74109', '12-31-2018', '4683388751179558', '1', 'burnt garlic tonkotsu ramen']
# ['74110', '12-31-2018', '4683388751179558', '1', 'burnt garlic tonkotsu ramen']
# ['74111', '12-31-2018', '4374384682408516', '1', 'truffle butter ramen']
# ['74112', '12-31-2018', '4374384682408516', '1', 'truffle butter ramen']
# ['74113', '12-31-2018', '5656600815381513', '2', 'miso crab ramen']
# ['74114', '12-31-2018', '5656600815381513', '2', 'miso crab ramen']
# ['74115', '12-31-2018', '73896627135443', '1', 'nagomi shoyu']
# ['74116', '12-31-2018', '73896627135443', '1', 'nagomi shoyu']
# ['74117', '12-31-2018', '1504475454920480', '1', 'tori paitan ramen']
# ['74118', '12-31-2018', '1504475454920480', '1', 'tori paitan ramen']
# ['74119', '12-31-2018', '1697055332228941', '4', 'tonkotsu ramen']
# ['74120', '12-31-2018', '1697055332228941', '4', 'tonkotsu ramen']
# ['74121', '12-31-2018', '6800009643487106', '1', 'vegetarian spicy miso']
# ['74122', '12-31-2018', '6800009643487106', '1', 'vegetarian spicy miso']
# ['74123', '12-31-2018', '5981057609583653', '2', 'spicy miso ramen']
# ['74124', '12-31-2018', '5981057609583653', '2', 'spicy miso ramen']
